# %%
import PBURF
# Out:
# ┌ Info: Recompiling stale cache file /Users/luhernan/.julia/compiled/v1.1/PBURF/Vb5hO.ji for PBURF [aec54e0c-fd3e-11e9-3925-dbf03be64f0c]
# └ @ Base loading.jl:1184

# %%
result=PBURF.plottingBasinsUnivariateRationalFunctions(PBURF.coefficientlistnumcompila, PBURF.coefficientlistdencompila)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x1328f39e8>
