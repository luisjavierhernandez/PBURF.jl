# %%
import Pkg

# %%
Pkg.update()
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/Google Drive/GitProjects/2019_gitprojects/PBURF/Project.toml`
#  [no changes]
#   Updating `~/Google Drive/GitProjects/2019_gitprojects/PBURF/Manifest.toml`
#  [no changes]

# %%
Pkg.status()
# Out:
# Project PBURF v0.1.0
#     Status `~/Google Drive/GitProjects/2019_gitprojects/PBURF/Project.toml`
#   [5ae59095] Colors v0.9.6
#   [f27b6e38] Polynomials v0.5.3
#   [d330b81b] PyPlot v2.8.2

# %%
import PBURF
# Out:
# ┌ Info: Precompiling PBURF [aec54e0c-fd3e-11e9-3925-dbf03be64f0c]
# └ @ Base loading.jl:1186

# %%
coefficientlistnumcompila=complex([1.,0.,0.,2.])
coefficientlistdencompila=complex([0.,0.,3.,0.])
result= PBURF.plottingBasinsUnivariateRationalFunctions(coefficientlistnumcompila,
    coefficientlistdencompila)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x13fc40828>

# %% [markdown]
# In rectangle above we obatin three basins of attraction. This appears  applying the Newton method  to compute the basins of the roots of the
# equation $x^3=1$.

# %%
resultaux= PBURF.aux_plottingBasinsUnivariateRationalFunctions(coefficientlistnumcompila,
    coefficientlistdencompila)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ((Tuple{Complex{Float64},Complex{Float64}}[(0.0+0.0im, 0.0+0.0im)], Tuple{Complex{Float64},Complex{Float64}}[(1.0+0.0im, 0.0+0.0im)], Tuple{Complex{Float64},Complex{Float64}}[(-0.5+0.866025im, 1.0+0.0im), (-0.5-0.866025im, 1.0+0.0im), (1.0+0.0im, 1.0+0.0im)]), ColorTypes.RGB{Float64}[RGB{Float64}(0.0,0.0,0.0), RGB{Float64}(0.5,0.5,0.5), RGB{Float64}(1.0,1.0,0.0), RGB{Float64}(1.0,0.0,0.0), RGB{Float64}(0.0,1.0,0.0), RGB{Float64}(0.0,0.0,1.0)], PyObject <matplotlib.image.AxesImage object at 0x1412d4160>)

# %%
resultaux[1]
# Out:
# (Tuple{Complex{Float64},Complex{Float64}}[(0.0+0.0im, 0.0+0.0im)], Tuple{Complex{Float64},Complex{Float64}}[(1.0+0.0im, 0.0+0.0im)], Tuple{Complex{Float64},Complex{Float64}}[(-0.5+0.866025im, 1.0+0.0im), (-0.5-0.866025im, 1.0+0.0im), (1.0+0.0im, 1.0+0.0im)])

# %%
resultaux[2]
# Out:
# 6-element Array{RGB{Float64},1} with eltype ColorTypes.RGB{Float64}:
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.5,0.5,0.5)
#  RGB{Float64}(1.0,1.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.0,1.0,0.0)
#  RGB{Float64}(0.0,0.0,1.0)

# %%
PBURF.plottingBasinsUnivariateRationalFunctions(coefficientlistnumcompila,
    coefficientlistdencompila; colorstrategy="iteration")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x140c33fd0>
